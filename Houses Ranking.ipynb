# %%
import numpy as np
import pandas as pd
import lightgbm as lgbm
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, make_scorer, mean_squared_log_error
from sklearn.pipeline import FeatureUnion, Pipeline
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import cross_validate, train_test_split

# %%
data = pd.read_csv('train.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])
data['Year'] = data['timestamp'].apply(lambda x: int(str(x)[:4]))
data['Month'] = data['timestamp'].apply(lambda x: int(str(x)[5:7]))
data['weekday'] = data['timestamp'].apply(lambda x: int(str(x)[8:10]))

target = data['price_doc']
data = data.drop(['timestamp', 'id', 'price_doc'], axis=1)

# %%
#numerical
num = data.select_dtypes(include=np.number)

#categorical
cat = data.select_dtypes(exclude=np.number)
for f in cat.columns:
    lbl = preprocessing.LabelEncoder()
    lbl.fit(list(cat[f].values))
    cat[f] = lbl.transform(list(cat[f].values))


train = pd.concat([cat, num], axis=1)
train = train.fillna(train.mean())
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
var = VarianceThreshold()
var.fit(train, target)

variances = dict(zip(train.columns, var.variances_))
sorted_vars = sorted(variances, key = variances.get)
corr = train.corr()

threshold = 0.8
low_vars = sorted_vars[:27]
corr_groups = []

for f in low_vars:
    high = corr[f][corr[f] >= threshold]
    corr_groups.append(high)

sorted_corr_groups = sorted(corr_groups, key=lambda x: x.size, reverse=True)
feat_list = sorted_corr_groups[0].index

# %%
def simple_model_validation(train, target):
    clf = lgbm.LGBMRegressor(boosting_type = 'gbdt')

    avg_err = 0
    for i in range(10):
        X_train, X_test, y_train, y_test = train_test_split(train, target)
        clf.fit(X_train, y_train)
        pred = clf.predict(X_test)

        error = mean_squared_log_error(pred, y_test)

        avg_err += error
    return avg_err.mean()


def special_model_validation(train, target, feat_list):
    clf = lgbm.LGBMRegressor(boosting_type = 'gbdt')
    reg = LinearRegression()

    avg_err = 0
    for i in range(10):
        X_train, X_test, y_train, y_test = train_test_split(train, target)
        for_reg_x = X_train.loc[:, feat_list]
        for_tree_x = X_train.drop(for_reg_x, axis=1)
        reg.fit(for_reg_x, y_train)
        reg_pred = reg.predict(for_reg_x)

        for_tree_x['reg'] = reg_pred
        clf.fit(for_tree_x, y_train)

        for_reg_x = X_test.loc[:, feat_list]
        for_tree_x = X_test.drop(for_reg_x, axis=1)
        reg_pred = reg.predict(for_reg_x)
        for_tree_x['reg'] = reg_pred
        pred = clf.predict(for_tree_x)

        error = mean_squared_log_error(pred, y_test)

        avg_err += error
    return avg_err.mean()

# %%
err1 = special_model_validation(train, target, feat_list)
err2 = simple_model_validation(train, target)
print("Model with regression : error =", err1)
print("Model without regression: error =", err2)
# Out:
# Model with regression : error = 2.2082528524403973
# Model without regression: error = 2.19655884298606

# %%
sorted_vars
# Out:
# ['mosque_count_500',
#  'oil_chemistry_raion',
#  'indust_part',
#  'mosque_count_1000',
#  'big_road1_1line',
#  'nuclear_reactor_raion',
#  'railroad_1line',
#  'green_zone_part',
#  'cafe_count_500_price_high',
#  'railroad_terminal_raion',
#  'mosque_count_1500',
#  'thermal_power_plant_raion',
#  'culture_objects_top_25',
#  'incineration_raion',
#  'water_1line',
#  'mosque_count_2000',
#  'big_market_raion',
#  'green_zone_km',
#  'detention_facility_raion',
#  'cafe_count_1000_price_high',
#  'school_education_centers_top_20_raion',
#  'leisure_count_500',
#  'market_count_500',
#  'water_km',
#  'university_top_20_raion',
#  'mosque_count_3000',
#  'radiation_raion',
#  'product_type',
#  'mosque_count_5000',
#  'state',
#  'cafe_count_500_price_4000',
#  'num_room',
#  'industrial_km',
#  'market_count_1000',
#  'church_synagogue_km',
#  'catering_km',
#  'cafe_count_1500_price_high',
#  'Year',
#  'build_count_foam',
#  'market_count_1500',
#  'big_church_count_500',
#  'ecology',
#  'material',
#  'trc_count_500',
#  'public_transport_station_km',
#  'big_road1_km',
#  'cafe_count_500_na_price',
#  'build_count_mix',
#  'market_count_2000',
#  'cemetery_km',
#  'healthcare_centers_raion',
#  'culture_objects_top_25_raion',
#  'additional_education_km',
#  'fitness_km',
#  'sport_count_500',
#  'cafe_count_2000_price_high',
#  'leisure_count_1000',
#  'big_road2_km',
#  'railroad_km',
#  'kindergarten_km',
#  'cafe_count_500_price_2500',
#  'church_count_500',
#  'shopping_centers_km',
#  'cafe_count_500_price_1000',
#  'market_count_3000',
#  'office_count_500',
#  'office_km',
#  'cafe_count_500_price_1500',
#  'big_church_count_1000',
#  'cafe_count_3000_price_high',
#  'hospice_morgue_km',
#  'big_church_km',
#  'preschool_education_centers_raion',
#  'preschool_km',
#  'school_km',
#  'cafe_count_500_price_500',
#  'cafe_count_1000_na_price',
#  'trc_count_1000',
#  'additional_education_raion',
#  'sport_count_1000',
#  'leisure_count_1500',
#  'school_education_centers_raion',
#  'market_shop_km',
#  'Month',
#  'ID_bus_terminal',
#  'railroad_station_walk_km',
#  'railroad_station_avto_km',
#  'cafe_count_1000_price_4000',
#  'park_km',
#  'public_healthcare_km',
#  'trc_count_1500',
#  'power_transmission_line_km',
#  'swim_pool_km',
#  'ice_rink_km',
#  'shopping_centers_raion',
#  'railroad_station_avto_min',
#  'ts_km',
#  'market_count_5000',
#  'workplaces_km',
#  'church_count_1000',
#  'mkad_km',
#  'exhibition_km',
#  'floor',
#  'basketball_km',
#  'cafe_count_5000_price_high',
#  'radiation_km',
#  'max_floor',
#  'thermal_power_plant_km',
#  'prom_part_5000',
#  'museum_km',
#  'sport_count_1500',
#  'metro_km_walk',
#  'mosque_km',
#  'metro_km_avto',
#  'cafe_count_1500_na_price',
#  'trc_count_2000',
#  'big_church_count_1500',
#  'metro_min_avto',
#  'sport_objects_raion',
#  'university_km',
#  'cafe_count_1500_price_4000',
#  'incineration_km',
#  'water_treatment_km',
#  'theater_km',
#  'leisure_count_2000',
#  'nuclear_reactor_km',
#  'bus_terminal_avto_km',
#  'cafe_count_1000_price_2500',
#  'stadium_km',
#  'prom_part_3000',
#  'ttk_km',
#  'sadovoe_km',
#  'kremlin_km',
#  'bulvar_ring_km',
#  'big_market_km',
#  'weekday',
#  'office_count_1000',
#  'cafe_count_1000_price_1000',
#  'sport_count_2000',
#  'prom_part_2000',
#  'cafe_count_2000_price_4000',
#  'church_count_1500',
#  'big_church_count_2000',
#  'cafe_count_2000_na_price',
#  'zd_vokzaly_avto_km',
#  'oil_chemistry_km',
#  'cafe_count_1000_price_1500',
#  'trc_count_3000',
#  'prom_part_1500',
#  'detention_facility_km',
#  'green_part_5000',
#  'cafe_count_500',
#  'ID_big_road1',
#  'prom_part_1000',
#  'prom_part_500',
#  'build_count_slag',
#  'leisure_count_3000',
#  'cafe_count_1500_price_2500',
#  'build_count_frame',
#  'cafe_count_1000_price_500',
#  'green_part_3000',
#  'green_part_2000',
#  'green_part_1500',
#  'green_part_1000',
#  'public_transport_station_min_walk',
#  'big_church_count_3000',
#  'church_count_2000',
#  'green_part_500',
#  'cafe_count_3000_price_4000',
#  'ID_big_road2',
#  'build_count_monolith',
#  'cafe_count_3000_na_price',
#  'sport_count_3000',
#  'leisure_count_5000',
#  'office_count_1500',
#  'cafe_count_1500_price_1000',
#  'cafe_count_2000_price_2500',
#  'kitch_sq',
#  'office_raion',
#  'trc_count_5000',
#  'cafe_count_1500_price_1500',
#  'cafe_count_1500_price_500',
#  'church_count_3000',
#  'ID_railroad_station_walk',
#  'cafe_count_5000_price_4000',
#  'big_church_count_5000',
#  'cafe_count_5000_na_price',
#  'ID_railroad_station_avto',
#  'ID_railroad_terminal',
#  'full_sq',
#  'office_count_2000',
#  'cafe_count_2000_price_500',
#  'cafe_count_2000_price_1500',
#  'sub_area',
#  'cafe_count_2000_price_1000',
#  'cafe_count_3000_price_2500',
#  'build_count_block',
#  'railroad_station_walk_min',
#  'sport_count_5000',
#  'life_sq',
#  'church_count_5000',
#  'cafe_count_1000',
#  'build_count_1971-1995',
#  'ID_metro',
#  'build_count_before_1920',
#  'build_count_1921-1945',
#  'metro_min_walk',
#  'cafe_count_3000_price_1000',
#  'cafe_count_3000_price_1500',
#  'cafe_count_3000_price_500',
#  'cafe_count_5000_price_2500',
#  'build_count_panel',
#  'office_count_3000',
#  'cafe_count_1500',
#  'build_count_after_1995',
#  'build_count_1946-1970',
#  'build_count_wood',
#  'build_count_brick',
#  'cafe_count_5000_price_1500',
#  'cafe_count_5000_price_500',
#  'cafe_count_5000_price_1000',
#  'cafe_sum_5000_min_price_avg',
#  'office_count_5000',
#  'cafe_count_2000',
#  'cafe_sum_1500_min_price_avg',
#  'cafe_avg_price_5000',
#  'cafe_sum_2000_min_price_avg',
#  'cafe_sum_1000_min_price_avg',
#  'cafe_sum_3000_min_price_avg',
#  'cafe_avg_price_1500',
#  'cafe_sum_5000_max_price_avg',
#  'cafe_avg_price_2000',
#  'cafe_avg_price_1000',
#  'raion_build_count_with_material_info',
#  'raion_build_count_with_builddate_info',
#  'cafe_sum_500_min_price_avg',
#  'cafe_sum_1500_max_price_avg',
#  'cafe_avg_price_3000',
#  'cafe_count_3000',
#  'cafe_sum_2000_max_price_avg',
#  'cafe_sum_1000_max_price_avg',
#  'cafe_avg_price_500',
#  'cafe_sum_3000_max_price_avg',
#  'cafe_sum_500_max_price_avg',
#  'cafe_count_5000',
#  'hospital_beds_raion',
#  '0_6_female',
#  'preschool_quota',
#  '7_14_female',
#  '0_6_male',
#  '7_14_male',
#  '0_13_female',
#  '0_13_male',
#  'school_quota',
#  'children_preschool',
#  '0_6_all',
#  'children_school',
#  '7_14_all',
#  'young_female',
#  'ekder_male',
#  'young_male',
#  '0_17_female',
#  '0_17_male',
#  '0_13_all',
#  'young_all',
#  'ekder_female',
#  '0_17_all',
#  'ekder_all',
#  'work_female',
#  'work_male',
#  '16_29_male',
#  '16_29_female',
#  'work_all',
#  'office_sqm_500',
#  'raion_popul',
#  '16_29_all',
#  'trc_sqm_500',
#  'build_year',
#  'male_f',
#  'office_sqm_1000',
#  'trc_sqm_1000',
#  'female_f',
#  'trc_sqm_1500',
#  'full_all',
#  'trc_sqm_2000',
#  'office_sqm_1500',
#  'trc_sqm_3000',
#  'office_sqm_2000',
#  'trc_sqm_5000',
#  'office_sqm_3000',
#  'office_sqm_5000',
#  'area_m']

# %%
full_sq	life_sq	floor area_m, build_year
# Out:
#        full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0           43     27.0    4.0        NaN       NaN         NaN       NaN
# 1           34     19.0    3.0        NaN       NaN         NaN       NaN
# 2           43     29.0    2.0        NaN       NaN         NaN       NaN
# 3           89     50.0    9.0        NaN       NaN         NaN       NaN
# 4           77     77.0    4.0        NaN       NaN         NaN       NaN
# 5           67     46.0   14.0        NaN       NaN         NaN       NaN
# 6           25     14.0   10.0        NaN       NaN         NaN       NaN
# 7           44     44.0    5.0        NaN       NaN         NaN       NaN
# 8           42     27.0    5.0        NaN       NaN         NaN       NaN
# 9           36     21.0    9.0        NaN       NaN         NaN       NaN
# 10          36     19.0   12.0        NaN       NaN         NaN       NaN
# 11          38     19.0   11.0        NaN       NaN         NaN       NaN
# 12          43     28.0    4.0        NaN       NaN         NaN       NaN
# 13          31     31.0    4.0        NaN       NaN         NaN       NaN
# 14          31     21.0    3.0        NaN       NaN         NaN       NaN
# 15          51     31.0   15.0        NaN       NaN         NaN       NaN
# 16          47     31.0    4.0        NaN       NaN         NaN       NaN
# 17          42     28.0    2.0        NaN       NaN         NaN       NaN
# 18          59     33.0   10.0        NaN       NaN         NaN       NaN
# 19          44     29.0    4.0        NaN       NaN         NaN       NaN
# 20          74     44.0   10.0        NaN       NaN         NaN       NaN
# 21          39     39.0    7.0        NaN       NaN         NaN       NaN
# 22          48     34.0    6.0        NaN       NaN         NaN       NaN
# 23          32     18.0    3.0        NaN       NaN         NaN       NaN
# 24          34     19.0   11.0        NaN       NaN         NaN       NaN
# 25          45     29.0    9.0        NaN       NaN         NaN       NaN
# 26          35     20.0    4.0        NaN       NaN         NaN       NaN
# 27          38     20.0    6.0        NaN       NaN         NaN       NaN
# 28          73     38.0   15.0        NaN       NaN         NaN       NaN
# 29          42     27.0    3.0        NaN       NaN         NaN       NaN
# ...        ...      ...    ...        ...       ...         ...       ...
# 30441      113      1.0   26.0       26.0       1.0      2015.0       4.0
# 30442       40     40.0    2.0       12.0       4.0      2015.0       1.0
# 30443       79      NaN   17.0       17.0       1.0         NaN       3.0
# 30444       85      NaN   20.0       25.0       4.0      2016.0       3.0
# 30445       47     47.0   19.0       25.0       1.0      2016.0       1.0
# 30446       82     82.0    8.0        8.0       6.0      2017.0       2.0
# 30447       64      NaN   15.0       17.0       1.0         NaN       2.0
# 30448       74      NaN    8.0       17.0       1.0         NaN       3.0
# 30449       47     47.0    7.0       25.0       1.0      2015.0       1.0
# 30450       65      NaN    5.0        0.0       1.0         NaN       2.0
# 30451       37      NaN    3.0        3.0       1.0         0.0       1.0
# 30452       38     19.0    7.0       17.0       1.0      2006.0       1.0
# 30453       45      1.0    6.0       15.0       6.0      2015.0       1.0
# 30454       40     26.0    3.0        9.0       2.0      1972.0       2.0
# 30455       79     79.0    3.0        3.0       1.0         NaN       3.0
# 30456       52     30.0    8.0       14.0       1.0      1992.0       2.0
# 30457       58     43.0    7.0        9.0       1.0      1979.0       3.0
# 30458       50      1.0    7.0        7.0       1.0      2015.0       1.0
# 30459       51      NaN    4.0       17.0       4.0         NaN       2.0
# 30460       54     32.0    8.0       16.0       1.0      1979.0       2.0
# 30461       36     19.0    5.0       16.0       1.0      1980.0       1.0
# 30462       47     30.0   23.0       25.0       4.0      2016.0       1.0
# 30463       56     29.0   13.0       14.0       1.0      2001.0       2.0
# 30464       56     51.0   19.0       19.0       1.0      2017.0       2.0
# 30465       52      NaN   13.0       17.0       1.0         NaN       2.0
# 30466       44     27.0    7.0        9.0       1.0      1975.0       2.0
# 30467       86     59.0    3.0        9.0       2.0      1935.0       4.0
# 30468       45      NaN   10.0       20.0       1.0         NaN       1.0
# 30469       64     32.0    5.0       15.0       1.0      2003.0       2.0
# 30470       43     28.0    1.0        9.0       1.0      1968.0       2.0
#
#        kitch_sq  state   product_type   ...    cafe_count_5000_price_high  \
# 0           NaN    NaN     Investment   ...                             0
# 1           NaN    NaN     Investment   ...                             0
# 2           NaN    NaN     Investment   ...                             0
# 3           NaN    NaN     Investment   ...                             1
# 4           NaN    NaN     Investment   ...                            17
# 5           NaN    NaN     Investment   ...                             1
# 6           NaN    NaN     Investment   ...                             3
# 7           NaN    NaN     Investment   ...                             0
# 8           NaN    NaN     Investment   ...                             1
# 9           NaN    NaN     Investment   ...                             0
# 10          NaN    NaN     Investment   ...                             0
# 11          NaN    NaN     Investment   ...                             0
# 12          NaN    NaN     Investment   ...                             1
# 13          NaN    NaN     Investment   ...                            22
# 14          NaN    NaN     Investment   ...                             2
# 15          NaN    NaN     Investment   ...                             0
# 16          NaN    NaN     Investment   ...                             0
# 17          NaN    NaN     Investment   ...                             0
# 18          NaN    NaN     Investment   ...                             0
# 19          NaN    NaN     Investment   ...                             0
# 20          NaN    NaN     Investment   ...                             0
# 21          NaN    NaN     Investment   ...                             0
# 22          NaN    NaN     Investment   ...                             1
# 23          NaN    NaN     Investment   ...                             0
# 24          NaN    NaN     Investment   ...                             1
# 25          NaN    NaN     Investment   ...                             1
# 26          NaN    NaN     Investment   ...                             0
# 27          NaN    NaN     Investment   ...                             0
# 28          NaN    NaN  OwnerOccupier   ...                             0
# 29          NaN    NaN     Investment   ...                             0
# ...         ...    ...            ...   ...                           ...
# 30441       1.0    1.0  OwnerOccupier   ...                            26
# 30442      10.0    1.0  OwnerOccupier   ...                             0
# 30443      79.0    1.0  OwnerOccupier   ...                             0
# 30444       1.0    1.0  OwnerOccupier   ...                             1
# 30445       1.0    1.0  OwnerOccupier   ...                            12
# 30446       1.0    1.0  OwnerOccupier   ...                             0
# 30447       1.0    NaN  OwnerOccupier   ...                             0
# 30448       1.0    NaN  OwnerOccupier   ...                             0
# 30449       1.0    1.0  OwnerOccupier   ...                            12
# 30450       0.0    NaN  OwnerOccupier   ...                             0
# 30451       1.0    1.0  OwnerOccupier   ...                             0
# 30452       7.0    3.0     Investment   ...                             0
# 30453       1.0    1.0  OwnerOccupier   ...                             0
# 30454       5.0    3.0     Investment   ...                             0
# 30455       1.0    NaN  OwnerOccupier   ...                             0
# 30456       8.0    2.0     Investment   ...                             1
# 30457       6.0    3.0     Investment   ...                             0
# 30458       0.0    1.0  OwnerOccupier   ...                             0
# 30459       1.0    1.0  OwnerOccupier   ...                             0
# 30460       9.0    2.0     Investment   ...                             0
# 30461       8.0    3.0     Investment   ...                             1
# 30462      10.0    1.0  OwnerOccupier   ...                            12
# 30463      11.0    3.0     Investment   ...                             0
# 30464       1.0    1.0  OwnerOccupier   ...                             0
# 30465       1.0    1.0  OwnerOccupier   ...                            26
# 30466       6.0    3.0     Investment   ...                             0
# 30467      10.0    3.0     Investment   ...                            24
# 30468       1.0    1.0  OwnerOccupier   ...                             0
# 30469      11.0    2.0     Investment   ...                             1
# 30470       6.0    2.0     Investment   ...                             0
#
#        big_church_count_5000  church_count_5000  mosque_count_5000  \
# 0                         13                 22                  1
# 1                         15                 29                  1
# 2                         11                 27                  0
# 3                          4                  4                  0
# 4                        135                236                  2
# 5                         53                 78                  1
# 6                         38                 80                  1
# 7                         11                 18                  1
# 8                         18                 34                  1
# 9                         10                 20                  1
# 10                         5                  9                  0
# 11                        10                  9                  0
# 12                         7                 15                  0
# 13                        57                102                  1
# 14                        63                100                  0
# 15                         9                 21                  0
# 16                         7                 23                  0
# 17                        13                 33                  1
# 18                         6                  9                  0
# 19                        10                 14                  0
# 20                         1                  5                  0
# 21                        12                 14                  0
# 22                        11                 10                  0
# 23                         7                 21                  1
# 24                         8                  9                  0
# 25                        11                 23                  1
# 26                        13                 25                  1
# 27                         2                 10                  0
# 28                        17                 35                  0
# 29                        12                 17                  0
# ...                      ...                ...                ...
# 30441                    150                249                  2
# 30442                      1                  7                  1
# 30443                      5                 14                  0
# 30444                      5                  7                  0
# 30445                     23                 42                  1
# 30446                      2                  9                  0
# 30447                      5                 14                  0
# 30448                      1                  7                  0
# 30449                     23                 42                  1
# 30450                     13                 28                  1
# 30451                      0                  0                  0
# 30452                      8                 23                  1
# 30453                      3                  8                  1
# 30454                     17                 29                  0
# 30455                      2                 12                  0
# 30456                      5                  7                  0
# 30457                      8                  7                  1
# 30458                      5                 15                  0
# 30459                      5                 14                  0
# 30460                      6                 25                  0
# 30461                      4                 35                  1
# 30462                     23                 42                  1
# 30463                     13                 12                  0
# 30464                     14                 29                  1
# 30465                    150                249                  2
# 30466                     15                 26                  1
# 30467                     98                182                  1
# 30468                      2                 12                  0
# 30469                      6                 31                  1
# 30470                      7                 16                  0
#
#        leisure_count_5000  sport_count_5000  market_count_5000  Year  Month  \
# 0                       0                52                  4  2011      8
# 1                      10                66                 14  2011      8
# 2                       4                67                 10  2011      8
# 3                       0                26                  3  2011      9
# 4                      91               195                 14  2011      9
# 5                      20               113                 17  2011      9
# 6                      27               127                  8  2011      9
# 7                       0                47                  4  2011      9
# 8                       3                85                 11  2011      9
# 9                       3                67                  1  2011      9
# 10                      2                17                  6  2011      9
# 11                      0                35                  4  2011      9
# 12                      2                47                  0  2011      9
# 13                     72               166                  7  2011      9
# 14                     28               132                 14  2011      9
# 15                      1                53                  9  2011      9
# 16                      4                62                 13  2011      9
# 17                     10                72                 12  2011      9
# 18                      2                17                  6  2011      9
# 19                      2                51                  5  2011      9
# 20                      0                 0                  0  2011      9
# 21                      1                64                  9  2011      9
# 22                      1                55                  8  2011      9
# 23                      1                42                 13  2011      9
# 24                      1                56                  8  2011      9
# 25                      4                70                  1  2011      9
# 26                      3                84                  4  2011      9
# 27                      1                11                  2  2011      9
# 28                      9                98                  7  2011      9
# 29                      3                73                  5  2011      9
# ...                   ...               ...                ...   ...    ...
# 30441                 105               203                 13  2015      6
# 30442                   0                12                  1  2015      6
# 30443                   3                17                  2  2015      6
# 30444                   1                38                  5  2015      6
# 30445                  13               123                  7  2015      6
# 30446                   0                 7                  2  2015      6
# 30447                   3                17                  2  2015      6
# 30448                   0                 8                  0  2015      6
# 30449                  13               123                  7  2015      6
# 30450                   3                84                  5  2015      6
# 30451                   0                 0                  0  2015      6
# 30452                   4                67                  2  2015      6
# 30453                   0                20                  3  2015      6
# 30454                   8                90                  4  2015      6
# 30455                   1                10                  0  2015      6
# 30456                   1                42                  6  2015      6
# 30457                   1                36                  1  2015      6
# 30458                   3                35                  3  2015      6
# 30459                   3                17                  2  2015      6
# 30460                   1                32                  8  2015      6
# 30461                   6                80                  6  2015      6
# 30462                  13               123                  7  2015      6
# 30463                   1                53                  6  2015      6
# 30464                   4                90                  6  2015      6
# 30465                 105               203                 13  2015      6
# 30466                   2                84                  6  2015      6
# 30467                  82               171                 15  2015      6
# 30468                   1                11                  1  2015      6
# 30469                   4                65                  7  2015      6
# 30470                   9                54                 10  2015      6
#
#        weekday
# 0           20
# 1           23
# 2           27
# 3            1
# 4            5
# 5            6
# 6            8
# 7            9
# 8           10
# 9           13
# 10          16
# 11          16
# 12          17
# 13          19
# 14          19
# 15          20
# 16          20
# 17          20
# 18          22
# 19          22
# 20          22
# 21          22
# 22          23
# 23          23
# 24          23
# 25          24
# 26          26
# 27          26
# 28          26
# 29          27
# ...        ...
# 30441       27
# 30442       27
# 30443       27
# 30444       27
# 30445       27
# 30446       27
# 30447       27
# 30448       27
# 30449       27
# 30450       29
# 30451       29
# 30452       29
# 30453       29
# 30454       29
# 30455       29
# 30456       29
# 30457       29
# 30458       29
# 30459       29
# 30460       29
# 30461       30
# 30462       30
# 30463       30
# 30464       30
# 30465       30
# 30466       30
# 30467       30
# 30468       30
# 30469       30
# 30470       30
#
# [30471 rows x 292 columns]

# %%
new_data = train.loc[:, ['full_sq', 'life_sq', 'area_m', 'build_year']]

# %%
clf = lgbm.LGBMRegressor(boosting_type = 'gbdt')

# %%
clf.fit(new_data, target)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#        learning_rate=0.1, max_depth=-1, min_child_samples=20,
#        min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#        n_jobs=-1, num_leaves=31, objective=None, random_state=None,
#        reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
#        subsample_for_bin=200000, subsample_freq=0)

# %%
pickle.dump(clf, open('model.pkl', 'wb'))

# %%
import pickle

# %%
clf.predict(new_data) 5490770.50179226
# Out:
# array([ 5490770.50179226,  5413002.39070529,  5881708.0251505 , ...,
#         5052983.86562188, 11574274.87576037,  6087462.46702136])

# %%
new_data['build_year'][30442]
# Out:
# 2015.0

# %%
d = data['build_year'][data['build_year'].notna()]

# %%
d.values
# Out:
# 20052009.0

# %%
d.values.
# Out:
# array([1907., 1980., 2014., ..., 1935., 2003., 1968.])
